# %%
from warnings import filterwarnings

from constants import DEFAULT_MARKET_PREFIXES
from market_data import AssetType
from plots import Plots
from util import Interval

filterwarnings('ignore')

asset_type = AssetType.DIGITAL
market_prefix = DEFAULT_MARKET_PREFIXES[asset_type]
signal_prefix = 'dseg'
bench_assets = ['BTC', 'ETH', 'ADA']

plot_service = Plots(bench_assets)

# %%
hourly_figs = plot_service.get(market_prefix, asset_type, signal_prefix, interval=Interval.HOUR)
hourly_figs[1].show()
# Out:
# Market data is getting updated.
# Update complete.
# Signal data is getting updated.
# Update complete.

# %%
daily_figs = plot_service.get(market_prefix, asset_type, signal_prefix, interval=Interval.DAY)
daily_figs[1].show()
# Out:
# Market data is getting updated.
# Update complete.
# Signal data is getting updated.
# Update complete.
